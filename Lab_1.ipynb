# %%
import pandas as pd

# %%
df = pd.read_csv("ML_Lab.csv")

# %%
df.columns
# Out:
# Index(['Serial No', 'Lectures Attended', 'Midsem Marks', 'Gender'], dtype='object')

# %%
df.head()
# Out:
#    Serial No  Lectures Attended  Midsem Marks Gender
# 0          1                 11            27      F
# 1          2                 15            58      M
# 2          3                 44            57      M
# 3          4                 26            43      M
# 4          5                 38            45      F

# %%
import matplotlib.pyplot as plt

# %%
 import seaborn as sns

# %%
plt.figure(figsize = (8,6))

# %%
sns.histplot(df['Midsem Marks'], color='purple')
# Out:
# <Axes: xlabel='Midsem Marks', ylabel='Count'>

# %%
sns.histplot(df['Midsem Marks'], bins=5, color='purple')
# Out:
# <Axes: xlabel='Midsem Marks', ylabel='Count'>

# %%
sns.scatterplot(x=df["Midsem Marks"], y=df["Lectures Attended"], hue=df['Gender'])
# Out:
# <Axes: xlabel='Midsem Marks', ylabel='Lectures Attended'>

# %%
sns.lineplot(x=df["Midsem Marks"], y=df["Lectures Attended"], hue=df['Gender'])
plt.title("student data")
# Out:
# Text(0.5, 1.0, 'student data')

# %%
sns.barplot(x=df["Midsem Marks"], y=df["Lectures Attended"], hue=df['Gender'])
plt.title("student data")
# Out:
# Text(0.5, 1.0, 'student data')

# %%
sns.boxplot(x=df["Midsem Marks"], y=df["Lectures Attended"], hue=df['Gender'])
plt.title("student data")
# Out:
# Text(0.5, 1.0, 'student data')

# %%
from scipy import stats
import numpy as np

# %%
mean_marks = np.mean(df['Midsem Marks'])

# %%
print(mean_marks)
# Out:
# 40.1

# %%
median_marks = np.median(df['Midsem Marks'])

# %%
print(median_marks)
# Out:
# 39.0

# %%
min_marks = np.min(df['Midsem Marks'])

# %%
print(min_marks)
# Out:
# 20

# %%
max_marks = np.max(df['Midsem Marks'])

# %%
print(max_marks)
# Out:
# 60

# %%
mode_marks = stats.mode(df['Midsem Marks'])

# %%
print(mode_marks)
# Out:
# ModeResult(mode=45, count=6)

# %%
mode_attendance = stats.mode(df['Lectures Attended'])

# %%
print(mode_attendance)
# Out:
# ModeResult(mode=39, count=6)

# %%
std_marks = np.std(df['Midsem Marks'],ddof=0)

# %%
print(std_marks)
# Out:
# 11.763927915454088

# %%
std_marks = np.std(df['Midsem Marks'],ddof=1)

# %%
print(std_marks)
# Out:
# 11.823192411014835

# %%
zscore_marks = stats.zscore(df['Midsem Marks'])

# %%
print(zscore_marks)
# Out:
# 0    -1.113574
# 1     1.521601
# 2     1.436595
# 3     0.246516
# 4     0.416528
#         ...
# 95   -0.433529
# 96    1.436595
# 97   -1.028568
# 98   -1.453596
# 99    1.096573
# Name: Midsem Marks, Length: 100, dtype: float64
