# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('smart_class_energy_data.csv')

# %%
df.head()
# Out:
#    Num_Students  Outdoor_Temp Time_of_Day   Humidity  Lights_On  Windows_Open  \
# 0            33     34.714868     Morning  69.221654          1             0
# 1            73     27.689434     Evening  75.267053          1             1
# 2            73     38.544262   Afternoon  69.683302          0             0
# 3             7     33.203330     Evening  89.243701          1             0
# 4            35     33.565462     Evening  68.174341          0             0
#
#    Fan_Speed    AC_Temp
# 0          2  26.911474
# 1          4  22.531882
# 2          3  23.523407
# 3          4  22.411541
# 4          1  26.139862

# %%
df.columns
# Out:
# Index(['Num_Students', 'Outdoor_Temp', 'Time_of_Day', 'Humidity', 'Lights_On',
#        'Windows_Open', 'Fan_Speed', 'AC_Temp'],
#       dtype='object')

# %%
df.dropna()
# Out:
#      Num_Students  Outdoor_Temp Time_of_Day   Humidity  Lights_On  \
# 0              33     34.714868     Morning  69.221654          1
# 1              73     27.689434     Evening  75.267053          1
# 2              73     38.544262   Afternoon  69.683302          0
# 3               7     33.203330     Evening  89.243701          1
# 4              35     33.565462     Evening  68.174341          0
# ..            ...           ...         ...        ...        ...
# 495            31     35.311169     Evening  71.632427          1
# 496            62     33.835296     Evening  77.747009          1
# 497            47     26.515593   Afternoon  78.597107          0
# 498            33     35.886481   Afternoon  59.353728          1
# 499            85     28.043010   Afternoon  58.647936          1
#
#      Windows_Open  Fan_Speed    AC_Temp
# 0               0          2  26.911474
# 1               1          4  22.531882
# 2               0          3  23.523407
# 3               0          4  22.411541
# 4               0          1  26.139862
# ..            ...        ...        ...
# 495             1          3  23.411115
# 496             0          4  21.676222
# 497             1          4  20.370864
# 498             1          5  20.237912
# 499             0          3  21.762938
#
# [500 rows x 8 columns]

# %%
le = LabelEncoder()
df["Time_of_Day"] = le.fit_transform(df["Time_of_Day"])

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#               Num_Students  Outdoor_Temp  Time_of_Day  Humidity  Lights_On  \
# Num_Students      1.000000     -0.069036     0.059211  0.082841  -0.014156
# Outdoor_Temp     -0.069036      1.000000    -0.047031 -0.047611  -0.082780
# Time_of_Day       0.059211     -0.047031     1.000000  0.076527  -0.048490
# Humidity          0.082841     -0.047611     0.076527  1.000000   0.071968
# Lights_On        -0.014156     -0.082780    -0.048490  0.071968   1.000000
# Windows_Open      0.038090     -0.090445     0.027964 -0.010494  -0.022996
# Fan_Speed         0.387247      0.166994     0.070672  0.320569   0.004290
# AC_Temp          -0.409075     -0.181758    -0.032646 -0.329279  -0.022950
#
#               Windows_Open  Fan_Speed   AC_Temp
# Num_Students      0.038090   0.387247 -0.409075
# Outdoor_Temp     -0.090445   0.166994 -0.181758
# Time_of_Day       0.027964   0.070672 -0.032646
# Humidity         -0.010494   0.320569 -0.329279
# Lights_On        -0.022996   0.004290 -0.022950
# Windows_Open      1.000000  -0.013696  0.018525
# Fan_Speed        -0.013696   1.000000 -0.635657
# AC_Temp           0.018525  -0.635657  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd



plt.figure(figsize=(10,6))  # Adjust figure size
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
print(type(plt))
# Out:
# <class 'module'>

# %%
# Calculate IQR
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# Remove outliers
df_no_outliers = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

print("Original DataFrame:\n", df)
print("\nDataFrame after removing outliers:\n",df_no_outliers)
# Out:
# Original DataFrame:
#       Num_Students  Outdoor_Temp  Time_of_Day   Humidity  Lights_On  \
# 0              33     34.714868            2  69.221654          1
# 1              73     27.689434            1  75.267053          1
# 2              73     38.544262            0  69.683302          0
# 3               7     33.203330            1  89.243701          1
# 4              35     33.565462            1  68.174341          0
# ..            ...           ...          ...        ...        ...
# 495            31     35.311169            1  71.632427          1
# 496            62     33.835296            1  77.747009          1
# 497            47     26.515593            0  78.597107          0
# 498            33     35.886481            0  59.353728          1
# 499            85     28.043010            0  58.647936          1
#
#      Windows_Open  Fan_Speed    AC_Temp
# 0               0          2  26.911474
# 1               1          4  22.531882
# 2               0          3  23.523407
# 3               0          4  22.411541
# 4               0          1  26.139862
# ..            ...        ...        ...
# 495             1          3  23.411115
# 496             0          4  21.676222
# 497             1          4  20.370864
# 498             1          5  20.237912
# 499             0          3  21.762938
#
# [500 rows x 8 columns]
#
# DataFrame after removing outliers:
#       Num_Students  Outdoor_Temp  Time_of_Day   Humidity  Lights_On  \
# 0              33     34.714868            2  69.221654          1
# 1              73     27.689434            1  75.267053          1
# 2              73     38.544262            0  69.683302          0
# 3               7     33.203330            1  89.243701          1
# 5              94     22.361869            2  85.740409          1
# ..            ...           ...          ...        ...        ...
# 495            31     35.311169            1  71.632427          1
# 496            62     33.835296            1  77.747009          1
# 497            47     26.515593            0  78.597107          0
# 498            33     35.886481            0  59.353728          1
# 499            85     28.043010            0  58.647936          1
#
#      Windows_Open  Fan_Speed    AC_Temp
# 0               0          2  26.911474
# 1               1          4  22.531882
# 2               0          3  23.523407
# 3               0          4  22.411541
# 5               1          3  21.425021
# ..            ...        ...        ...
# 495             1          3  23.411115
# 496             0          4  21.676222
# 497             1          4  20.370864
# 498             1          5  20.237912
# 499             0          3  21.762938
#
# [457 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

# Plot the original data
plt.figure(figsize=(10, 5))
plt.plot(df.index, df.mean(axis=1), label="Original Data", linestyle='dashed', color='red')

# Plot the cleaned data (without outliers)
plt.plot(df_no_outliers.index, df_no_outliers.mean(axis=1), label="Without Outliers", color='blue')

# Labels and title
plt.xlabel("Index")
plt.ylabel("Mean Value of Rows")
plt.title("Line Graph Before and After Removing Outliers")
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
x=df.drop(columns=['AC_Temp'])

# %%
y=df['AC_Temp']

# %%
print(x)
# Out:
#      Num_Students  Outdoor_Temp  Time_of_Day   Humidity  Lights_On  \
# 0              33     34.714868            2  69.221654          1
# 1              73     27.689434            1  75.267053          1
# 2              73     38.544262            0  69.683302          0
# 3               7     33.203330            1  89.243701          1
# 4              35     33.565462            1  68.174341          0
# ..            ...           ...          ...        ...        ...
# 495            31     35.311169            1  71.632427          1
# 496            62     33.835296            1  77.747009          1
# 497            47     26.515593            0  78.597107          0
# 498            33     35.886481            0  59.353728          1
# 499            85     28.043010            0  58.647936          1
#
#      Windows_Open  Fan_Speed
# 0               0          2
# 1               1          4
# 2               0          3
# 3               0          4
# 4               0          1
# ..            ...        ...
# 495             1          3
# 496             0          4
# 497             1          4
# 498             1          5
# 499             0          3
#
# [500 rows x 7 columns]

# %%
print(y)
# Out:
# 0      26.911474
# 1      22.531882
# 2      23.523407
# 3      22.411541
# 4      26.139862
#          ...
# 495    23.411115
# 496    21.676222
# 497    20.370864
# 498    20.237912
# 499    21.762938
# Name: AC_Temp, Length: 500, dtype: float64

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=20,random_state=40)

# %%
model=LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
print(mse)
# Out:
# 1.9205853624119662

# %%
r2=r2_score(y_test,y_pred)

# %%
print(r2)
# Out:
# 0.5078275137110092

# %%
# Step 1: Define a new sample input
new_sample = np.array([[55,32.145236,2,85.456921,0,1,3]])  # Replace with actual values

# Step 2: Ensure the input has the correct shape
new_sample = new_sample.reshape(1, -1)  # Reshape for a single sample

# Step 3: Predict output using the trained model
prediction = model.predict(new_sample)

# Step 4: Display Prediction
print(f"Predicted Output: {prediction[0]}")
# Out:
# Predicted Output: 22.846852197340358
# c:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
